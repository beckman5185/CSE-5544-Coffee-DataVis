# %%
import pandas as pd

# %%
df= pd.read_csv("coffee_survey.csv")

# %%
df.head(10)
# Out:
#   submission_id              age         cups  \
# 0        gMR29l  18-24 years old          NaN
# 1        BkPN0e  25-34 years old          NaN
# 2        W5G8jj  25-34 years old          NaN
# 3        4xWgGr  35-44 years old          NaN
# 4        QD27Q8  25-34 years old          NaN
# 5        V0LPeM  55-64 years old          NaN
# 6        V0Gaxg  18-24 years old          NaN
# 7        AdzRL0              NaN          NaN
# 8        LbWda2  25-34 years old  Less than 1
# 9        EXQLWN              NaN          NaN
#
#                                     where_drink  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6  At a cafe, At the office, At home, On the go
# 7                                           NaN
# 8                                     At a cafe
# 9                                           NaN
#
#                                                 brew brew_other  \
# 0                                                NaN        NaN
# 1        Pod/capsule machine (e.g. Keurig/Nespresso)        NaN
# 2                                Bean-to-cup machine        NaN
# 3           Coffee brewing machine (e.g. Mr. Coffee)        NaN
# 4                                          Pour over        NaN
# 5  Pod/capsule machine (e.g. Keurig/Nespresso), E...        NaN
# 6  Pour over, French press, Espresso, Instant cof...        NaN
# 7                                                NaN        NaN
# 8                                                NaN        NaN
# 9                                                NaN        NaN
#
#                                             purchase purchase_other  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# 6  National chain (e.g. Starbucks, Dunkin), Local...            NaN
# 7                                                NaN            NaN
# 8                                                NaN            NaN
# 9                                                NaN            NaN
#
#               favorite favorite_specify  ... spent_equipment value_equipment  \
# 0  Regular drip coffee              NaN  ...             NaN             NaN
# 1          Iced coffee              NaN  ...             NaN             NaN
# 2  Regular drip coffee              NaN  ...             NaN             NaN
# 3          Iced coffee              NaN  ...             NaN             NaN
# 4                Latte              NaN  ...             NaN             NaN
# 5          Iced coffee              NaN  ...             NaN             NaN
# 6             Pourover              NaN  ...             NaN             NaN
# 7                  NaN              NaN  ...             NaN             NaN
# 8  Regular drip coffee              NaN  ...             NaN             NaN
# 9                  NaN              NaN  ...             NaN             NaN
#
#   gender gender_specify education_level ethnicity_race ethnicity_race_specify  \
# 0    NaN            NaN             NaN            NaN                    NaN
# 1    NaN            NaN             NaN            NaN                    NaN
# 2    NaN            NaN             NaN            NaN                    NaN
# 3    NaN            NaN             NaN            NaN                    NaN
# 4    NaN            NaN             NaN            NaN                    NaN
# 5    NaN            NaN             NaN            NaN                    NaN
# 6    NaN            NaN             NaN            NaN                    NaN
# 7    NaN            NaN             NaN            NaN                    NaN
# 8    NaN            NaN             NaN            NaN                    NaN
# 9    NaN            NaN             NaN            NaN                    NaN
#
#   employment_status  number_children  political_affiliation
# 0               NaN              NaN                    NaN
# 1               NaN              NaN                    NaN
# 2               NaN              NaN                    NaN
# 3               NaN              NaN                    NaN
# 4               NaN              NaN                    NaN
# 5               NaN              NaN                    NaN
# 6               NaN              NaN                    NaN
# 7               NaN              NaN                    NaN
# 8               NaN              NaN                    NaN
# 9               NaN              NaN                    NaN
#
# [10 rows x 57 columns]

# %%
df.describe()
# Out:
#          expertise  coffee_a_bitterness  coffee_a_acidity  \
# count  3938.000000          3798.000000       3779.000000
# mean      5.693499             2.141127          3.634824
# std       1.948867             0.947163          0.982113
# min       1.000000             1.000000          1.000000
# 25%       5.000000             1.000000          3.000000
# 50%       6.000000             2.000000          4.000000
# 75%       7.000000             3.000000          4.000000
# max      10.000000             5.000000          5.000000
#
#        coffee_a_personal_preference  coffee_b_bitterness  coffee_b_acidity  \
# count                   3789.000000          3780.000000       3767.000000
# mean                       3.310900             3.013228          2.223786
# std                        1.185953             0.992875          0.865389
# min                        1.000000             1.000000          1.000000
# 25%                        2.000000             2.000000          2.000000
# 50%                        3.000000             3.000000          2.000000
# 75%                        4.000000             4.000000          3.000000
# max                        5.000000             5.000000          5.000000
#
#        coffee_b_personal_preference  coffee_c_bitterness  coffee_c_acidity  \
# count                   3773.000000          3764.000000       3751.000000
# mean                       3.068646             3.071998          2.366836
# std                        1.113546             0.999267          0.921048
# min                        1.000000             1.000000          1.000000
# 25%                        2.000000             2.000000          2.000000
# 50%                        3.000000             3.000000          2.000000
# 75%                        4.000000             4.000000          3.000000
# max                        5.000000             5.000000          5.000000
#
#        coffee_c_personal_preference  coffee_d_bitterness  coffee_d_acidity  \
# count                   3766.000000          3767.000000       3765.000000
# mean                       3.064790             2.162729          3.858167
# std                        1.128431             1.081546          1.007973
# min                        1.000000             1.000000          1.000000
# 25%                        2.000000             1.000000          3.000000
# 50%                        3.000000             2.000000          4.000000
# 75%                        4.000000             3.000000          5.000000
# max                        5.000000             5.000000          5.000000
#
#        coffee_d_personal_preference
# count                   3764.000000
# mean                       3.375930
# std                        1.452504
# min                        1.000000
# 25%                        2.000000
# 50%                        4.000000
# 75%                        5.000000
# max                        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4042 non-null   object
#  1   age                           4011 non-null   object
#  2   cups                          3949 non-null   object
#  3   where_drink                   3972 non-null   object
#  4   brew                          3657 non-null   object
#  5   brew_other                    678 non-null    object
#  6   purchase                      710 non-null    object
#  7   purchase_other                31 non-null     object
#  8   favorite                      3980 non-null   object
#  9   favorite_specify              114 non-null    object
#  10  additions                     3959 non-null   object
#  11  additions_other               48 non-null     object
#  12  dairy                         1686 non-null   object
#  13  sweetener                     512 non-null    object
#  14  style                         3958 non-null   object
#  15  strength                      3916 non-null   object
#  16  roast_level                   3940 non-null   object
#  17  caffeine                      3917 non-null   object
#  18  expertise                     3938 non-null   float64
#  19  coffee_a_bitterness           3798 non-null   float64
#  20  coffee_a_acidity              3779 non-null   float64
#  21  coffee_a_personal_preference  3789 non-null   float64
#  22  coffee_a_notes                2578 non-null   object
#  23  coffee_b_bitterness           3780 non-null   float64
#  24  coffee_b_acidity              3767 non-null   float64
#  25  coffee_b_personal_preference  3773 non-null   float64
#  26  coffee_b_notes                2454 non-null   object
#  27  coffee_c_bitterness           3764 non-null   float64
#  28  coffee_c_acidity              3751 non-null   float64
#  29  coffee_c_personal_preference  3766 non-null   float64
#  30  coffee_c_notes                2382 non-null   object
#  31  coffee_d_bitterness           3767 non-null   float64
#  32  coffee_d_acidity              3765 non-null   float64
#  33  coffee_d_personal_preference  3764 non-null   float64
#  34  coffee_d_notes                2588 non-null   object
#  35  prefer_abc                    3772 non-null   object
#  36  prefer_ad                     3761 non-null   object
#  37  prefer_overall                3770 non-null   object
#  38  wfh                           3524 non-null   object
#  39  total_spend                   3511 non-null   object
#  40  why_drink                     3568 non-null   object
#  41  why_drink_other               167 non-null    object
#  42  taste                         3563 non-null   object
#  43  know_source                   3559 non-null   object
#  44  most_paid                     3527 non-null   object
#  45  most_willing                  3510 non-null   object
#  46  value_cafe                    3500 non-null   object
#  47  spent_equipment               3506 non-null   object
#  48  value_equipment               3494 non-null   object
#  49  gender                        3523 non-null   object
#  50  gender_specify                12 non-null     object
#  51  education_level               3438 non-null   object
#  52  ethnicity_race                3418 non-null   object
#  53  ethnicity_race_specify        105 non-null    object
#  54  employment_status             3419 non-null   object
#  55  number_children               856 non-null    object
#  56  political_affiliation         3289 non-null   object
# dtypes: float64(13), object(44)
# memory usage: 1.8+ MB

# %%
df['total_spend']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 4037    $20-$40
# 4038    $20-$40
# 4039    $40-$60
# 4040    $20-$40
# 4041    $20-$40
# Name: total_spend, Length: 4042, dtype: object

# %%
df['total_spend']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 4037    $20-$40
# 4038    $20-$40
# 4039    $40-$60
# 4040    $20-$40
# 4041    $20-$40
# Name: total_spend, Length: 4042, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4042 entries, 0 to 4041
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   submission_id                 4042 non-null   object
#  1   age                           4011 non-null   object
#  2   cups                          3949 non-null   object
#  3   where_drink                   3972 non-null   object
#  4   brew                          3657 non-null   object
#  5   brew_other                    678 non-null    object
#  6   purchase                      710 non-null    object
#  7   purchase_other                31 non-null     object
#  8   favorite                      3980 non-null   object
#  9   favorite_specify              114 non-null    object
#  10  additions                     3959 non-null   object
#  11  additions_other               48 non-null     object
#  12  dairy                         1686 non-null   object
#  13  sweetener                     512 non-null    object
#  14  style                         3958 non-null   object
#  15  strength                      3916 non-null   object
#  16  roast_level                   3940 non-null   object
#  17  caffeine                      3917 non-null   object
#  18  expertise                     3938 non-null   float64
#  19  coffee_a_bitterness           3798 non-null   float64
#  20  coffee_a_acidity              3779 non-null   float64
#  21  coffee_a_personal_preference  3789 non-null   float64
#  22  coffee_a_notes                2578 non-null   object
#  23  coffee_b_bitterness           3780 non-null   float64
#  24  coffee_b_acidity              3767 non-null   float64
#  25  coffee_b_personal_preference  3773 non-null   float64
#  26  coffee_b_notes                2454 non-null   object
#  27  coffee_c_bitterness           3764 non-null   float64
#  28  coffee_c_acidity              3751 non-null   float64
#  29  coffee_c_personal_preference  3766 non-null   float64
#  30  coffee_c_notes                2382 non-null   object
#  31  coffee_d_bitterness           3767 non-null   float64
#  32  coffee_d_acidity              3765 non-null   float64
#  33  coffee_d_personal_preference  3764 non-null   float64
#  34  coffee_d_notes                2588 non-null   object
#  35  prefer_abc                    3772 non-null   object
#  36  prefer_ad                     3761 non-null   object
#  37  prefer_overall                3770 non-null   object
#  38  wfh                           3524 non-null   object
#  39  total_spend                   3511 non-null   object
#  40  why_drink                     3568 non-null   object
#  41  why_drink_other               167 non-null    object
#  42  taste                         3563 non-null   object
#  43  know_source                   3559 non-null   object
#  44  most_paid                     3527 non-null   object
#  45  most_willing                  3510 non-null   object
#  46  value_cafe                    3500 non-null   object
#  47  spent_equipment               3506 non-null   object
#  48  value_equipment               3494 non-null   object
#  49  gender                        3523 non-null   object
#  50  gender_specify                12 non-null     object
#  51  education_level               3438 non-null   object
#  52  ethnicity_race                3418 non-null   object
#  53  ethnicity_race_specify        105 non-null    object
#  54  employment_status             3419 non-null   object
#  55  number_children               856 non-null    object
#  56  political_affiliation         3289 non-null   object
# dtypes: float64(13), object(44)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#   submission_id              age cups where_drink  \
# 0        gMR29l  18-24 years old  NaN         NaN
# 1        BkPN0e  25-34 years old  NaN         NaN
# 2        W5G8jj  25-34 years old  NaN         NaN
# 3        4xWgGr  35-44 years old  NaN         NaN
# 4        QD27Q8  25-34 years old  NaN         NaN
#
#                                           brew brew_other purchase  \
# 0                                          NaN        NaN      NaN
# 1  Pod/capsule machine (e.g. Keurig/Nespresso)        NaN      NaN
# 2                          Bean-to-cup machine        NaN      NaN
# 3     Coffee brewing machine (e.g. Mr. Coffee)        NaN      NaN
# 4                                    Pour over        NaN      NaN
#
#   purchase_other             favorite favorite_specify  ... spent_equipment  \
# 0            NaN  Regular drip coffee              NaN  ...             NaN
# 1            NaN          Iced coffee              NaN  ...             NaN
# 2            NaN  Regular drip coffee              NaN  ...             NaN
# 3            NaN          Iced coffee              NaN  ...             NaN
# 4            NaN                Latte              NaN  ...             NaN
#
#   value_equipment gender gender_specify education_level ethnicity_race  \
# 0             NaN    NaN            NaN             NaN            NaN
# 1             NaN    NaN            NaN             NaN            NaN
# 2             NaN    NaN            NaN             NaN            NaN
# 3             NaN    NaN            NaN             NaN            NaN
# 4             NaN    NaN            NaN             NaN            NaN
#
#   ethnicity_race_specify employment_status  number_children  \
# 0                    NaN               NaN              NaN
# 1                    NaN               NaN              NaN
# 2                    NaN               NaN              NaN
# 3                    NaN               NaN              NaN
# 4                    NaN               NaN              NaN
#
#    political_affiliation
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 57 columns]

# %%
df.dropna(subset=['total_spend'], inplace=True)
df['total_spend']
# Out:
# 15        >$100
# 17      $40-$60
# 34      $20-$40
# 41      $40-$60
# 42      $20-$40
#          ...
# 4037    $20-$40
# 4038    $20-$40
# 4039    $40-$60
# 4040    $20-$40
# 4041    $20-$40
# Name: total_spend, Length: 3511, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['total_spend'], bins=20, edgecolor='black')
plt.xlabel('Total Spend')
plt.ylabel('Frequency')
plt.title('Money Spent in a month')
plt.show()

# %%
# grouped_by_age = df.groupby('age')['total_spend'].mean()
# grouped_by_age

# %%
# df_cleaned = df.dropna(subset=['total_spend'])

# # Define bins and labels for spend range bins = [20, 40, 60, 80, 100, float('inf')]
# labels = ['20-40', '40-60', '60-80', '80-100']
# bins = [20, 40, 60, 80, float('inf')]

# # Create a new column categorizing each spend into these ranges
# df_cleaned['spend_range'] = pd.cut(df_cleaned['total_spend'], bins=bins, labels=labels, right=False)
# grouped_spent_equipment = df.groupby(['age', 'spent_equipment']).size().unstack(fill_value=0)

# # Count frequency of each spend range
# spend_range_counts = df_cleaned['spend_range'].value_counts().sort_index()

# spend_range_counts

# %%
grouped_spent_equipment = df.groupby(['age', 'total_spend']).size().unstack(fill_value=0)
grouped_spent_equipment
# Out:
# total_spend      $20-$40  $40-$60  $60-$80  $80-$100  <$20  >$100
# age
# 18-24 years old      176       89       28        13    70      8
# 25-34 years old      663      564      196       107   208     56
# 35-44 years old      268      270      113        63    84     52
# 45-54 years old       92       74       28        27    22     11
# 55-64 years old       63       36       14        10    24      1
# <18 years old          3        3        1         0     5      1
# >65 years old         28       14        7         3    14      2

# %%
#percentage
grouped_spent_equipment = df.groupby(['age', 'total_spend']).size().unstack(fill_value=0)

grouped_spent_equipment_percentage = grouped_spent_equipment.div(grouped_spent_equipment.sum(axis=1), axis=0) * 100

grouped_spent_equipment_percentage
# Out:
# total_spend        $20-$40    $40-$60    $60-$80   $80-$100       <$20  \
# age
# 18-24 years old  45.833333  23.177083   7.291667   3.385417  18.229167
# 25-34 years old  36.956522  31.438127  10.925307   5.964326  11.594203
# 35-44 years old  31.529412  31.764706  13.294118   7.411765   9.882353
# 45-54 years old  36.220472  29.133858  11.023622  10.629921   8.661417
# 55-64 years old  42.567568  24.324324   9.459459   6.756757  16.216216
# <18 years old    23.076923  23.076923   7.692308   0.000000  38.461538
# >65 years old    41.176471  20.588235  10.294118   4.411765  20.588235
#
# total_spend         >$100
# age
# 18-24 years old  2.083333
# 25-34 years old  3.121516
# 35-44 years old  6.117647
# 45-54 years old  4.330709
# 55-64 years old  0.675676
# <18 years old    7.692308
# >65 years old    2.941176

# %%
#graph

import matplotlib.pyplot as plt

grouped_spent_equipment_percentage.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Age')
plt.ylabel('Percentage')
plt.title('Percentage of Total Spend by Age and Equipment')
plt.legend(title='Total Spend')
plt.show()

# %%
grouped_spent_equipment_g = df.groupby(['gender', 'total_spend']).size().unstack(fill_value=0)
grouped_spent_equipment_g
# Out:
# total_spend             $20-$40  $40-$60  $60-$80  $80-$100  <$20  >$100
# gender
# Female                      289      208       83        52   177     24
# Male                        929      795      285       157   225     98
# Non-binary                   42       23       12         8    11      5
# Other (please specify)        4        2        2         0     1      1
# Prefer not to say            14       10        2         3     2      1

# %%
grouped_spent_equipment_percentage_g = grouped_spent_equipment_g.div(grouped_spent_equipment_g.sum(axis=1), axis=0) * 100

grouped_spent_equipment_percentage_g
# Out:
# total_spend               $20-$40    $40-$60    $60-$80  $80-$100       <$20  \
# gender
# Female                  34.693878  24.969988   9.963986  6.242497  21.248499
# Male                    37.324227  31.940538  11.450382  6.307754   9.039775
# Non-binary              41.584158  22.772277  11.881188  7.920792  10.891089
# Other (please specify)  40.000000  20.000000  20.000000  0.000000  10.000000
# Prefer not to say       43.750000  31.250000   6.250000  9.375000   6.250000
#
# total_spend                 >$100
# gender
# Female                   2.881152
# Male                     3.937324
# Non-binary               4.950495
# Other (please specify)  10.000000
# Prefer not to say        3.125000

# %%
grouped_spent_equipment_percentage_g.plot(kind='bar', figsize=(10, 6))
plt.xlabel('gender')
plt.ylabel('Percentage')
plt.title('Percentage of Total Spend by gender and Equipment')
plt.legend(title='Total Spend')
plt.show()

# %%
df["most_paid"]
# Out:
# 15          NaN
# 17          NaN
# 34        $4-$6
# 41        $2-$4
# 42      $10-$15
#          ...
# 4037      $6-$8
# 4038      $4-$6
# 4039     $8-$10
# 4040      $4-$6
# 4041    $15-$20
# Name: most_paid, Length: 3511, dtype: object

# %%
grouped_spent_equipment_e = df.groupby(['ethnicity_race', 'total_spend']).size().unstack(fill_value=0)
grouped_spent_equipment_e
# Out:
# total_spend                    $20-$40  $40-$60  $60-$80  $80-$100  <$20  \
# ethnicity_race
# Asian/Pacific Islander             157      112       35        19    58
# Black/African American              12        9        4         4     7
# Hispanic/Latino                     81       57       26         9    32
# Native American/Alaska Native        5        4        2         1     1
# Other (please specify)              39       32        8         8    19
# White/Caucasian                    953      791      297       172   287
#
# total_spend                    >$100
# ethnicity_race
# Asian/Pacific Islander            22
# Black/African American             1
# Hispanic/Latino                    7
# Native American/Alaska Native      0
# Other (please specify)             2
# White/Caucasian                   94

# %%
grouped_spent_equipment_percentage_e= grouped_spent_equipment_e.div(grouped_spent_equipment_e.sum(axis=1), axis=0) * 100

grouped_spent_equipment_percentage_e
# Out:
# total_spend                      $20-$40    $40-$60    $60-$80   $80-$100  \
# ethnicity_race
# Asian/Pacific Islander         38.957816  27.791563   8.684864   4.714640
# Black/African American         32.432432  24.324324  10.810811  10.810811
# Hispanic/Latino                38.207547  26.886792  12.264151   4.245283
# Native American/Alaska Native  38.461538  30.769231  15.384615   7.692308
# Other (please specify)         36.111111  29.629630   7.407407   7.407407
# White/Caucasian                36.738628  30.493446  11.449499   6.630686
#
# total_spend                         <$20     >$100
# ethnicity_race
# Asian/Pacific Islander         14.392060  5.459057
# Black/African American         18.918919  2.702703
# Hispanic/Latino                15.094340  3.301887
# Native American/Alaska Native   7.692308  0.000000
# Other (please specify)         17.592593  1.851852
# White/Caucasian                11.063994  3.623747

# %%
grouped_spent_equipment_ed = df.groupby(['education_level', 'total_spend']).size().unstack(fill_value=0)
grouped_spent_equipment_ed
# Out:
# total_spend                         $20-$40  $40-$60  $60-$80  $80-$100  <$20  \
# education_level
# Bachelor's degree                       641      548      189       107   199
# Doctorate or professional degree        111      110       39        21    26
# High school graduate                     52       20       15         6    19
# Less than high school                     3        6        3         1     8
# Master's degree                         258      218       89        52    82
# Some college or associate's degree      185      114       41        27    69
#
# total_spend                         >$100
# education_level
# Bachelor's degree                      55
# Doctorate or professional degree       24
# High school graduate                    4
# Less than high school                   1
# Master's degree                        24
# Some college or associate's degree     19

# %%
grouped_spent_equipment_percentage_ed= grouped_spent_equipment_ed.div(grouped_spent_equipment_ed.sum(axis=1), axis=0) * 100

grouped_spent_equipment_percentage_ed
# Out:
# total_spend                           $20-$40    $40-$60    $60-$80  $80-$100  \
# education_level
# Bachelor's degree                   36.860265  31.512363  10.868315  6.152961
# Doctorate or professional degree    33.534743  33.232628  11.782477  6.344411
# High school graduate                44.827586  17.241379  12.931034  5.172414
# Less than high school               13.636364  27.272727  13.636364  4.545455
# Master's degree                     35.684647  30.152144  12.309820  7.192254
# Some college or associate's degree  40.659341  25.054945   9.010989  5.934066
#
# total_spend                              <$20     >$100
# education_level
# Bachelor's degree                   11.443358  3.162737
# Doctorate or professional degree     7.854985  7.250755
# High school graduate                16.379310  3.448276
# Less than high school               36.363636  4.545455
# Master's degree                     11.341632  3.319502
# Some college or associate's degree  15.164835  4.175824

# %%
grouped_spent_equipment_percentage_ed.plot(kind='bar', figsize=(10, 6))
plt.xlabel('education_level')
plt.ylabel('Percentage')
plt.title('Percentage of Total Spend by education and Equipment')
plt.legend(title='Total Spend')
plt.show()

# %%
grouped_most_willing_age = df.groupby(['age', 'most_willing']).size().unstack(fill_value=0)
grouped_most_willing_age
# Out:
# most_willing     $10-$15  $15-$20  $2-$4  $4-$6  $6-$8  $8-$10  Less than $2  \
# age
# 18-24 years old       76       30      6     33     79      91             1
# 25-34 years old      374      189     29    116    303     458             6
# 35-44 years old      135       80     11     86    147     208             3
# 45-54 years old       43       17      9     39     56      54             4
# 55-64 years old       14        4     14     36     33      37             2
# <18 years old          1        0      0      0      5       3             0
# >65 years old          6        3     11     15     13      13             3
#
# most_willing     More than $20
# age
# 18-24 years old             64
# 25-34 years old            302
# 35-44 years old            167
# 45-54 years old             29
# 55-64 years old              4
# <18 years old                3
# >65 years old                1

# %%
grouped_spent_equipment_percentage_age= grouped_most_willing_age.div(grouped_most_willing_age.sum(axis=1), axis=0) * 100

grouped_spent_equipment_percentage_age
# Out:
# most_willing       $10-$15    $15-$20      $2-$4      $4-$6      $6-$8  \
# age
# 18-24 years old  20.000000   7.894737   1.578947   8.684211  20.789474
# 25-34 years old  21.046708  10.635903   1.631964   6.527856  17.051210
# 35-44 years old  16.129032   9.557945   1.314217  10.274791  17.562724
# 45-54 years old  17.131474   6.772908   3.585657  15.537849  22.310757
# 55-64 years old   9.722222   2.777778   9.722222  25.000000  22.916667
# <18 years old     8.333333   0.000000   0.000000   0.000000  41.666667
# >65 years old     9.230769   4.615385  16.923077  23.076923  20.000000
#
# most_willing        $8-$10  Less than $2  More than $20
# age
# 18-24 years old  23.947368      0.263158      16.842105
# 25-34 years old  25.773776      0.337648      16.994935
# 35-44 years old  24.850657      0.358423      19.952210
# 45-54 years old  21.513944      1.593625      11.553785
# 55-64 years old  25.694444      1.388889       2.777778
# <18 years old    25.000000      0.000000      25.000000
# >65 years old    20.000000      4.615385       1.538462

# %%
grouped_spent_equipment_percentage_age.plot(kind='line', figsize=(10, 6))
plt.xlabel('education_level')
plt.ylabel('Percentage')
plt.title('Percentage of Total Spend by education and Equipment')
plt.legend(title='Total Spend')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(grouped_spent_equipment_percentage_age, annot=True, fmt=".1f")
plt.title("Heatmap of Percentage of Total Spend by Age and Most Willing")
plt.xlabel("Most Willing")
plt.ylabel("Age")
plt.show()

# %%
grouped_spent_equipment_po = df.groupby(['number_children', 'most_willing']).size().unstack(fill_value=0)
grouped_spent_equipment_po
# Out:
# most_willing     $10-$15  $15-$20  $2-$4  $4-$6  $6-$8  $8-$10  Less than $2  \
# number_children
# 1                     51       33      7     29     57      69             2
# 2                     61       26     19     62     74      93             2
# 3                     17        7      8     17     18      17             0
# More than 3            6        4      4      5     11      17             0
#
# most_willing     More than $20
# number_children
# 1                           52
# 2                           50
# 3                            5
# More than 3                  4
